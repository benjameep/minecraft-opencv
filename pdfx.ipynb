# %%
from src import Frame, Rectangle, VideoReader, VideoWriter
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

# %%
frame = Frame.from_file('/Users/bearl/Downloads/paychex-w2-full.jpg')
frame[600:1100,:,:]
plt.show()

# %%
frame.canny(100, 250)
plt.show()[750:

# %%
contours = [contour for contour in frame.gray().invert().dilate(7).median_blur(13).erode(7).invert().find_contours()]
rectangles = [Rectangle.from_contour(contour, mode='bound') for contour in contours]
rectangles = [rect for rect in rectangles if rect.area]
# display((frame*0).draw_rectangles(rectangles, color=(255,255,255))[650:1200,100:-100,0])
display((frame*0).draw_contours(contours, color=(255,255,255))[650:1200,100:-100,0])
# display((frame*0).draw_lines(frame.gray().hough_lines(), color=(255,255,255))[650:1200,100:-100,0])
plt.show()
# Out:
# <Frame (550, 1500)>

# %%
display(frame.gray().invert().dilate(7).median_blur(13).erode(7)[650:1200,100:-100])
# display((frame*0).draw_lines(frame.gray().invert().dilate(8).erode(8).canny(100,250).hough_lines(maxLineGap=3))[650:1200,100:-100])
plt.show()
# Out:
# <Frame (550, 1500)>
